# %% [markdown]
# ##**Data Visualization**

# %% [markdown]
# 3.1) **Line Chart**

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#Store marks and no. of study hours
marks = [98,60,5,72,80]
std_hours =[10,6,5,7,8]

#Create a line chart using marks on x-axis and y-axis
plt.plot(marks,std_hours)

#Add a title to the chart

plt.title("Line Chart")

#Add label to the x-axis
plt.xlabel("Marks")

#Add label to the y-axis
plt.ylabel("Hours")

#Display the line chart
plt.show()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#Store marks and no. of study hours
marks = [98,60,5,72,80]
std_hours =[10,6,5,7,8]

#Create a line chart using marks on x-axis and study hours on y-axis
plt.plot(marks,std_hours)

#Add a title to the chart
plt.title("Line Chart")

#Add label to  x-axis
plt.xlabel("Marks")

#Add label to y-axis
plt.ylabel("Hours")

#Create a line chart using marks on x-axis and study hours on y-axis can customize with marker and line with linestyle.
plt.plot(marks,std_hours,marker ='s',linestyle = ':')

#Display the line chart
plt.show()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#Store marks and hours of study
marks = [98,60,5,72,80]
std_hours =[10,6,5,7,8]

#Create a line chart using marks on x-axis and study hours on y-axis
plt.plot(marks,std_hours)

#Add a title to the chart
plt.title("Line Chart")

#Add label to x-axis
plt.xlabel("Marks")

#Add label to y-axis
plt.ylabel("Hours")

#Create a line chart using marks on x-axis and study hours on y-axis customize with marker and linestyle
plt.plot(marks,std_hours,marker ='s',linestyle = ':')

#Add a title to the chart
plt.title("Line Chart",fontsize = 14, color = "green")

#Create a line chart using marks on x-axis and study hours on y-axis
plt.plot(marks,std_hours)

#Add a label to x-axis
plt.xlabel("Marks",fontsize = 12, color="red")

#Add a label to y-axis
plt.ylabel("Hours",fontsize = 12, color="red")

#Display the line chart
plt.show()

# %%
#Store marks and hours of study
marks = [98,60,5,72,80]
std_hours =[10,6,5,7,8]

#Create a line chart using marks on x-axis and study hours on y-axis
plt.plot(marks,std_hours)

#Add a title to line chart
plt.title("Line Chart")

#Add label to x-axis
plt.xlabel("Marks")

#Add label y-axis
plt.ylabel("Hours")

#Create a line chart using marks on x-axis and study hours on y-axis customize with markers and line with linestyle
plt.plot(marks,std_hours,marker ='s',linestyle = ':')

#Add title to the line chart
plt.title("Line Chart",fontsize = 14, color = "green")

#Add grid to line chart
plt.grid(True)

#Add labels to x-axis
plt.xlabel("Marks",fontsize = 12, color="red")

#Add labels to y-axis
plt.ylabel("Hours",fontsize = 12, color="red")

#Create a line chart using marks on x-axis and study hours on y-axis
plt.plot(marks,std_hours)

#Display the line chart
plt.show()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#Store marks and study hours
marks = [98,60,5,72,80]
std_hours =[10,6,5,7,8]

#
plt.figure(figsize=(5,5))

#Create a line chart using marks on x-axis and study hours on y-axis
plt.plot(marks,std_hours)

#Add a title on line chart
plt.title("Line Chart",fontsize = 14, color = "green")

#Add label to x-axis
plt.xlabel("Marks",fontsize = 12, color="red")

#Add label to y-axis
plt.ylabel("Hours", fontsize = 12, color="red")



#Create a line chart using marks on x-axis and study hours on y-axis customize with markers and line with linestyle
plt.plot(marks,std_hours,marker ='s',linestyle = ':')


plt.grid(True)

#Display the line chart
plt.show()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt
#Import pandas library for data handling
import pandas as pd

#Create a student dictionary containin marks
student ={
    "marks":[20,30,40,50,60]
}

#Convert the dictionary into the dataframe
df=pd.DataFrame(student)

#Set the size of the figure
plt.figure(figsize=(5,5))

#Plot the marks as a line chart
plt.plot(df["marks"])

#Add a title to the line chart
plt.title("Line Chart")

#Add label to x-axis
plt.xlabel("Marks")

#Add label to y-axis
plt.ylabel("Hours")

#Customize the line with marker and line style
plt.plot(df["marks"],marker ='s',linestyle = ':')

#Customize the title with font size and color
plt.title("Line Chart",fontsize = 14, color = "green")

#Display rid lines on the chart
plt.grid(True)

#Customize the xlabel
plt.xlabel("Marks",fontsize = 12, color="red")

#Customize the ylabel
plt.ylabel("Hours",fontsize = 12, color="red")

#Create a line chart
plt.plot(marks,std_hours)

#Display the line chart
plt.show()

# %%
#Store the marks and study hours
marks = [98,60,5,72,80]
std_hours =[10,6,5,7,8]

#Crete a line chart
plt.plot(marks,std_hours)

#Add labels to the data points
for i in range(len(marks)):
  plt.text(marks[i],std_hours[i], str([marks[i],std_hours[i]]))

  #Add the title of the line chart
plt.title("Line Chart")

#Add label to the x-axis
plt.xlabel("Marks")

#Add label to the y-axis
plt.ylabel("Hours")

#Display the line chart
plt.show()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#import pandas library of python
import pandas as pd

# Sample data for Month and Profit
data = {"Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul"],
        "Profit": [100, 120, 150, 130, 180, 160, 200]}

#Create a data frame
df = pd.DataFrame(data)

#Create a line chart
plt.plot(df["Month"], df["Profit"], marker="o")

#Add title on line chart
plt.title("Month vs Profit")

#Add label on x-axis
plt.xlabel("Month")

#Add label on y-axis
plt.ylabel("Profit")

#Display the line chart
plt.show()

# %% [markdown]
# 3.2) **Histogram**

# %%
#Store age
age = [10,20,30,20,10,20,30,40,50,50]

#Creating an historam
plt.hist(age)

#Add a title to the histogram
plt.title("Histogram")

#Add label to x-axis
plt.xlabel("Age")

#Add label to y-axis
plt.ylabel("Frequency")

#Display the histogram
plt.show()

# %%
#Store age
age = [10,20,30,20,10,20,30,40,50,50,50,60]

#Create a histogram on x-axis and y-axis
plt.hist(age,bins =3,edgecolor = "r",color="y",alpha = 0.6)

#Display grid on histogram
plt.grid(axis='y')

#Add title on the histogram
plt.title("Histogram")

#Add label to x-axis
plt.xlabel("Age")

#Add label to y-axis
plt.ylabel("Frequency")

#Display the line chart
plt.show()

# %%
plt.hist(df["marks"],bins =3,edgecolor = "r",color="y",alpha = 0.6)

#Display  the histogram
plt.show()

# %%
#Import numpy library
import numpy as np

#Store age in a list
age = [20, 19, 8, 19, 16, 20, 21, 23, 28, 19, 23]

#Create a histogram and customize it with color, alpha, edgecolor, bins
plt.hist(age, bins=3, edgecolor='r', color='yellow',alpha=0.5)

# Add a title to the histogram
plt.title("Age comparison", fontsize=22, color="green")

# Add a label to the x-axis
plt.xlabel("age", fontsize=12, color="red")

# Add horizontal grid lines
plt.grid(axis='y')

# Add a label to the y-axis
plt.ylabel("", fontsize=12, color="red")

#Calculate the median of the age values
median_age = np.median(age)

#Add a vertical line to show the median age
plt.axvline(median_age,color='blue',linestyle='--',linewidth=3.5,label=f'Median = {median_age}')

#Display the legend
plt.legend()

#Display th histogram
plt.show()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#Create a histogram
plt.hist(df["Profit"], bins=10)

#Add a title on line chart
plt.title("Profit Distribution")

#Add label at x-axis
plt.xlabel("Profit")

#Add label at y-axis
plt.ylabel("Frequency")

#Display the hsitogram
plt.show()

# %% [markdown]
# **3.3 Bar Chart**

# %%
#Store subjects and store
subjects=["python","c","java","DSA"]
score=[40,60,65,85]

#Create a bar chart and customie it with color
plt.bar(subjects,score,color=["r","green","y","pink"])

#Add a title and customize the title
plt.title("Subject vs Score",color='r')

#Add a label to x-axis and customize it with color
plt.xlabel("Subjects",color='r')

#Add a label to y-axis and customize it with color
plt.ylabel("Score",color='r')

#Display the grid
plt.grid(axis='y')

#Display the output
plt.show()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#Create a bar chart
plt.bar(df["Month"], df["Profit"])

#Add title on the bar chart
plt.title("Month vs Profit")

#Add label at x-axis
plt.xlabel("Month")

#Add label at y-axis
plt.ylabel("Profit")

#Display the bar chart
plt.show()

# %% [markdown]
# 3.4) **Pie Chart**

# %%
#Store subject and sccore
subject=["Techical","english","Gk","apptitude"]
score=[40,60,65,85]

#Create a pie chart and customize it
plt.pie(score,labels=subject,autopct="%1.2f%%")

#Add a title on pie chart and customize it with color
plt.title("Subject vs Score",color='r')

#Display the pie chart
plt.show()

# %%
#Store subject and score
subject=["Techical","english","Gk","apptitude"]
score=[40,60,65,85]

#Create a pie chart and customize it
plt.pie(score,labels=subject,autopct="%1.1f%%",startangle=55)

#Add title on pie chart and customize it with color
plt.title("Subject vs Score",color='r')

#Display the pie chart
plt.show()

# %%
#Store subject and score
subject=["Techical","english","Gk","apptitude"]
score=[40,60,65,85]

#Create a pie chart and customizing it
plt.pie(score,labels=subject,autopct="%1.1f%%",startangle=45,explode=(0.1,0,0,0))

#Add title and customize it with color
plt.title("Subject vs Score",color='r')

#Disply the pie chart
plt.show()

# %%
#Store subject and store
subject=["Techical","english","Gk","apptitude"]
score=[40,60,65,85]

#Create pie chart and customize it
plt.pie(score,labels=subject,autopct="%1.1f%%",startangle=45,explode=(0.1,0,0,0),shadow=True)

#Add title and customize it with color
plt.title("Subject vs Score",color='r')

#Display the piechart
plt.show()

# %%
#Store subject, score and colors
subject=["Techical","english","Gk","apptitude"]
score=[40,60,65,85]
colors=["r","green","y","pink"]

#Create a pie chart and customize it
plt.pie(score,labels=subject, colors=colors,autopct="%1.1f%%",startangle=45,explode=(0.1,0,0,0),shadow=True)

#Add title on pie chart
plt.title("Subject vs Score",color='r')

#Display the pie chart
plt.show()

# %%
#Store subject and score
subject=["Techical","english","Gk","apptitude"]
score=[40,60,65,85]

#Create a pie chart and customize it
plt.pie(score,labels=subject,autopct="%1.1f%%",startangle=45,explode=(0.1,0,0,0),shadow=True)

#Add title and customize it with colors and alpha
plt.title("Subject vs Score",color='r',alpha=0.)

#display the legend in upper right corner of pie chart
plt.legend(loc="upper right")

#Display the pie chart
plt.show()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#Group the data and calculate the total profit for each month
profit_by_month = df.groupby("Month")["Profit"].sum()

#Create a pie chart to show the profit
plt.pie(
    profit_by_month,
    labels=profit_by_month.index,
    autopct="%1.1f%%"
)

#Add a title to the pie chart

plt.title("Profit Contribution by Month")

#Display the pie chart
plt.show()

# %% [markdown]
# **3.5 Scatter Plot**

# %%
import matplotlib.pyplot as plt

#Store variales
x1 = [2, 4, 6, 8, 100]
y1 = [11, 13, 15, 17, 19]

#store two more ariables
x2 = [12, 14, 16, 18, 90]
y2 = [1, 3, 5, 7, 9]

#Add colour and size
rang = ["pink", "purple", "orange", 'red', "green"]
size = [100, 200, 300, 400, 500]

#Create scatter plot
plt.scatter(x1, y1, color = rang, s = size, alpha = 0.5)
plt.scatter(x2, y2, color = rang, s = size, alpha = 0.8)

#Display the legend
plt.legend()

#Display the scatter plot
plt.show()
# Out:
# /tmp/ipykernel_555/1544429466.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Import matplotlib pyplot module for creating charts
import matplotlib.pyplot as plt

#Create scatter plot
plt.scatter(df["Month"], df["Profit"])

#Add title on scatter plot
plt.title("Month vs Profit")

#Add label at x-axis
plt.xlabel("Month")

#Add label at y-axis
plt.ylabel("Profit")

#Display the scatter plot
plt.show()
