# %% [markdown]
# #**Basics** **of** **python**

# %% [markdown]
# 1. Write a program to print basic string

# %%
#WAP to print basic string
print(''' "farman's house" ''')#print name
# Out:
#  "farman's house"

# %% [markdown]
# ##sum code

# %% [markdown]
# 2. Write a program to print the sum of two numbers without taking variable

# %%
#WAP to sum of two numbers without taking variable
print( 5 + 10)
# Out:
# 15

# %% [markdown]
# 3. Write a program to print the sum of two numbers with variable

# %%
#WAP to sum of two numbers with variable
a = 5 #assign number 1
b = 4 #assign number 2
sum = a + b
print(sum)
# Out:
# 9

# %% [markdown]
# 4. Write a program to divide using //

# %%
#WAP to divide using //
a = 7
b = 3
print(a//b) #print output in integer
# Out:
# 2

# %% [markdown]
# #**Operators**

# %% [markdown]
# 5. Write a program using operators
# (relational operator,
# logical operator)

# %%
#WAP to compare two values
a = 10
b = 10
print(a == b) #relational operator
# Out:
# True

# %%
#WAP to compare two values
a = 1
b = 2
print(a <= b) #relational operator
# Out:
# True

# %%
#WAP to print True or False
print(False and True) #loigcal operator using and
# Out:
# False

# %%
#WAP to print True or False
print(True and False) #using and logical operator
print(True and True)
print(False and False)
# Out:
# False
# True
# False

# %%
#logical operator
print(True or False) #using or
print(False or True)
print(True or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
#logical operator
print(not False) #using not
print(not True)
# Out:
# True
# False

# %%
#WAP to compare two values using and logical operator
a = 5
b = 4
print(a>b and b<a)
# Out:
# True

# %%
#WAP to compare two values using or logical operator
a = 5
b = 4
print (a>b or b<a)
# Out:
# True

# %% [markdown]
# #**Input**

# %% [markdown]
# 6. Write the programs by taking the input from the user in python

# %%
#WAP by taking input
a = 5
b = "4"
sum = a + int(b)
print(sum)
# Out:
# 9

# %%
#WAP by taking input from the user
name = input("Enter your name: ")    #input from the user(name)
print(name)                          #print name
age = int(input("enter your age: ")) #input from the user(age)
print(age)                           #print age
# Out:
# kanishka
# enter your age: 21
# 21

# %%
#WAP to find the area of square by taking input from the user
side = int(input("Enter the side:"))      #input from the user
area = side*side                          #formula
print(area)                               #print area
# Out:
# Enter the side:4
# 16
